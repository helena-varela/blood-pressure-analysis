# %% [markdown]
# # **Libraries used**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # **Data Collection**

# %%
# Collects a week's data and stores it in lists
systolic = []
diastolic = []

for i in range(1, 8):
  print(f"Day {i}")
  s = int(input("Systolic pressure: "))
  d= int(input("Diastolic pressure: "))
  systolic.append(s)
  diastolic.append(d)
# Out:
# Day 1
# Systolic pressure: 122
# Diastolic pressure: 79
# Day 2
# Systolic pressure: 119
# Diastolic pressure: 82
# Day 3
# Systolic pressure: 125
# Diastolic pressure: 85
# Day 4
# Systolic pressure: 130
# Diastolic pressure: 78
# Day 5
# Systolic pressure: 118
# Diastolic pressure: 75
# Day 6
# Systolic pressure: 123
# Diastolic pressure: 80
# Day 7
# Systolic pressure: 127
# Diastolic pressure: 83

# %% [markdown]
# # **Graph Plotting**

# %%
x = np.arange(1, 8)

# Graph Plotting
plt.plot(x, systolic, 'r-o', label = "Systolic (mmHg)", linewidth=2, markersize=8 )
plt.plot(x, diastolic, 'b-o', label = "Diastolic (mmHg)", linewidth=2, markersize=8 )

# Graph Minimum and Maximum
min_val = min(min(systolic), min(diastolic)) - 8
max_val = max(max(systolic), max(diastolic)) + 8

# Add the point values
for i in range(len(x)):
    plt.annotate(f'{systolic[i]}', (x[i], systolic[i]), textcoords="offset points", xytext=(0,10), ha='center', fontsize=8)
    plt.annotate(f'{diastolic[i]}', (x[i], diastolic[i]), textcoords="offset points", xytext=(0,-15), ha='center', fontsize=8)

# Visual elements
plt.xticks(x, ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.yticks(np.arange(min_val, max_val + 1, 5))
plt.xlabel('Days of the week')
plt.ylabel('Blood pressure (mmHg)')
plt.title('Blood Pressure Variation')
plt.legend(loc='center')
plt.grid(True)
plt.show()
